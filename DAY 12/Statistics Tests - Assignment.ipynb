# %%
import pandas as pd

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\sharath max'

# %%
cd C:\Users\sharath max\Desktop\lets upgrade\day 7
# Out:
# C:\Users\sharath max\Desktop\lets upgrade\day 7

# %%
dataset =pd.read_csv("general_data.csv")

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df=dataset.dropna()

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df1=df.drop_duplicates()

# %%
df1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df2=df1[df1["Attrition"]=="Yes"]

# %%
df2
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4381   29       Yes      Travel_Rarely  Research & Development
# 4386   33       Yes      Travel_Rarely                   Sales
# 4388   33       Yes      Travel_Rarely                   Sales
# 4391   32       Yes      Travel_Rarely                   Sales
# 4402   37       Yes  Travel_Frequently                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                   10          1  Life Sciences              1           2
# ...

# %%
df3=df1[df1["Attrition"]=="No"]

# %%
df3
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# 5      46        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# # Attrition vs DistanceFromHome

# %%
from scipy.stats import mannwhitneyu

# %%
stats,p=mannwhitneyu(df2.DistanceFromHome,df3.DistanceFromHome)

# %%
print(stats,p)
# Out:
# 1295261.0 0.488538986087403

# %% [markdown]
# ___As the P value of  is > 0.05, the H0 is accepted and Ha is rejected___
#
# ___H0: There is no significant differences in the Attrition and DistanceFromHome___
#
# ___Ha: There is significant differences  between Attrition  and DistanceFromHome___

# %% [markdown]
# # Attrition vs MonthlyIncome

# %%
from scipy.stats import mannwhitneyu

# %%
mannwhitneyu(df2.MonthlyIncome,df3.MonthlyIncome)
# Out:
# MannwhitneyuResult(statistic=1249573.5, pvalue=0.06508807631576838)

# %% [markdown]
# ___As the P value is > than 0.05, the H0 is accepted and Ha is rejected___
#
# ___H0: There is no significant differences  between Attrition  and MonthlyIncome___
#
# ___Ha: There is significant differences  between Attrition and MonthlyIncome___

# %% [markdown]
# # Attrition vs Age

# %%
mannwhitneyu(df2.Age,df3.Age)
# Out:
# MannwhitneyuResult(statistic=949178.0, pvalue=7.98668614365882e-30)

# %% [markdown]
# ___As the P value is < than 0.05, the H0 is rejected and Ha is accepted.___
#
# ___H0: There is no significant differences between Attrition and Age___
#
# ___Ha: There is significant differences between Attrition and Age___

# %% [markdown]
# # Attrition vs TotalWorkingYears

# %%
stats,p=mannwhitneyu(df2.TotalWorkingYears,df3.TotalWorkingYears)

# %%
print(stats,p)
# Out:
# 895173.5 2.741211827689903e-39

# %%
print(p)
# Out:
# 2.741211827689903e-39

# %% [markdown]
# ___As the P value is < than 0.05, the H0 is rejected and Ha is accepted.___
#
# ___H0: There is no significant difference between Attrition and TotalWorkingYears___
#
# ___Ha: There is significant differences between Attrition and TotalWorkingYears___

# %% [markdown]
# # Attrition vs YearsAtCompany

# %%
stats,p=mannwhitneyu(df2.YearsAtCompany,df3.YearsAtCompany)

# %%
print(stats,p)
# Out:
# 912579.0 3.3433144809752036e-36

# %%
print(p)
# Out:
# 3.3433144809752036e-36

# %% [markdown]
# ___As the P value is < than 0.05, the H0 is rejected and Ha is accepted.___
#
# ___H0: There is no significant differences  between Attrition and YearsAtCompany___
#
# ___Ha: There is significant differences between Attrition and YearsAtCompany___

# %% [markdown]
# # Attrition Vs YearsWithCurrManager

# %%
stats,p=mannwhitneyu(df2.YearsWithCurrManager,df3.YearsWithCurrManager)

# %%
print(stats,p)
# Out:
# 945958.5 5.420302388722274e-31

# %%
print(p)
# Out:
# 5.420302388722274e-31

# %% [markdown]
# ___As the P value is < than 0.05, the H0 is rejected and Ha is accepted.___
#
# ___H0: There is no significant differences  between Attrition and YearsWithCurrManager___
#
# ___Ha: There is significant differences between Attrition and YearsWithCurrManager___

# %% [markdown]
# # Attrition vs YearsSinceLastPromotion

# %%
stats,p=mannwhitneyu(df2.YearsSinceLastPromotion,df3.YearsSinceLastPromotion)

# %%
print(stats,p)
# Out:
# 1196606.0 0.00037904698157957496

# %%
print(p)
# Out:
# 0.00037904698157957496

# %% [markdown]
# ___As the P value is < than 0.05, the H0 is rejected and Ha is accepted.___
#
# ___H0: There is no significant differences between Attrition and YearsSinceLastPromotion___
#
# ___Ha: There is significant differences between Attrition and YearsSinceLastPromotion___
